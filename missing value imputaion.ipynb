# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## severe

# %%
df_s=pd.read_csv('/content/gdrive/My Drive/new covid project work/df_s_remove_outlier.csv')
df_sev= df_s.set_index('Protein IDs')
df_sev
# Out:
#                   Q9NYW8      P59594  ...       Q14624      Q71U36
# Protein IDs                           ...
#  SOP62        10803000.0         NaN  ...          NaN         NaN
#  SOP67       130670000.0  11676000.0  ...          NaN     93420.0
#  SOP73               NaN  10370000.0  ...   86596000.0   1384200.0
#  SOP79       101100000.0         NaN  ...   89621000.0     36790.0
#  SOP80               NaN   4516900.0  ...   71157000.0    426820.0
#  SOP82       100530000.0   7222400.0  ...   83714000.0         NaN
#  SOP83               NaN  12005000.0  ...  103640000.0    338130.0
#  SOP84        87820000.0  12170000.0  ...  150430000.0         NaN
#  SOP85       166070000.0   9797400.0  ...  110600000.0  14751000.0
#  OP34          9823600.0         NaN  ...   47155000.0    224330.0
#  OP37         20407000.0   8502900.0  ...  108400000.0         NaN
#  OP40                NaN   6805800.0  ...   89444000.0         NaN
# ...

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_knn_s = pd.DataFrame(imputer.fit_transform(df_sev),columns = df_sev.columns)
df_knn_s
# Out:
#          Q9NYW8      P59594  A0A0C4DH42  ...      Q03591       Q14624      Q71U36
# 0    10803000.0   9771860.0   1867160.0  ...  17859000.0  104484600.0   3398714.0
# 1   130670000.0  11676000.0   1867160.0  ...  22050400.0  104484600.0     93420.0
# 2    94740600.0  10370000.0   2847100.0  ...  35840000.0   86596000.0   1384200.0
# 3   101100000.0   8050220.0   2299200.0  ...  23634000.0   89621000.0     36790.0
# 4    94740600.0   4516900.0   1006100.0  ...  20664000.0   71157000.0    426820.0
# 5   100530000.0   7222400.0   2840200.0  ...  13889000.0   83714000.0   7940024.0
# 6    94740600.0  12005000.0   1906800.0  ...  20914000.0  103640000.0    338130.0
# 7    87820000.0  12170000.0   2048000.0  ...  22050400.0  150430000.0   3398714.0
# 8   166070000.0   9797400.0   1527800.0  ...  14975000.0  110600000.0  14751000.0
# 9     9823600.0   8050220.0   2299200.0  ...  13210000.0   47155000.0    224330.0
# ...

# %%
df_ns=pd.read_csv('/content/gdrive/My Drive/new covid project work/df_ns_remove_outlier.csv')
df_nsev= df_ns.set_index('Protein IDs')
df_nsev
# Out:
#                  Q9H0K6       Q9NYW8  ...       Q14624      Q71U36
# Protein IDs                           ...
#  NSOP_13      5865400.0   75304000.0  ...   57836000.0     80530.0
#  NSOP_15      3445900.0   45686000.0  ...   60063000.0   4594400.0
#  OP1          9311000.0          NaN  ...  140250000.0         NaN
#  OP10         6671700.0          NaN  ...  140740000.0    183870.0
#  OP19         3153200.0   42895000.0  ...   33027000.0    139680.0
#  OP2                NaN  112670000.0  ...  195570000.0    552480.0
#  OP20         2271500.0   17927000.0  ...   20064000.0    122640.0
#  OP21         2116400.0   10829000.0  ...   17897000.0    123790.0
#  OP3          7179200.0  249540000.0  ...  118470000.0         NaN
#  OP4         11305000.0  193020000.0  ...   64981000.0    844420.0
#  OP5          3913800.0  121770000.0  ...  189140000.0         NaN
#  OP6                NaN   15387000.0  ...  220410000.0   6054700.0
# ...

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_knn_ns = pd.DataFrame(imputer.fit_transform(df_nsev),columns = df_nsev.columns)
df_knn_ns
# Out:
#         Q9H0K6       Q9NYW8       Q569K6  ...      Q03591       Q14624      Q71U36
# 0    5865400.0   75304000.0   33081000.0  ...   3111900.0   57836000.0     80530.0
# 1    3445900.0   45686000.0   43359000.0  ...  11319000.0   60063000.0   4594400.0
# 2    9311000.0  102030600.0   54723000.0  ...  41447000.0  140250000.0   6344030.0
# 3    6671700.0  163545400.0  174830000.0  ...  25145000.0  140740000.0    183870.0
# 4    3153200.0   42895000.0  194974200.0  ...   8360400.0   33027000.0    139680.0
# 5   26883800.0  112670000.0  285040000.0  ...  29276000.0  195570000.0    552480.0
# 6    2271500.0   17927000.0  169246000.0  ...   5605600.0   20064000.0    122640.0
# 7    2116400.0   10829000.0  169246000.0  ...   4840700.0   17897000.0    123790.0
# 8    7179200.0  249540000.0  247690000.0  ...  18504000.0  118470000.0   4166294.0
# 9   11305000.0  193020000.0  247022000.0  ...  35978000.0   64981000.0    844420.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# %%
scaler = MinMaxScaler()
# transform data
Min_Max_scaled = scaler.fit_transform(df_knn_s)
df_minmax_s = pd.DataFrame(Min_Max_scaled)
df_minmax_s
# Out:
#          0         1         2    ...       200       201       202
# 0   0.006268  0.686645  0.467713  ...  0.323163  0.555116  0.141721
# 1   0.773435  0.935451  0.467713  ...  0.480934  0.555116  0.002387
# 2   0.543481  0.764801  1.000000  ...  1.000000  0.381903  0.056800
# 3   0.584182  0.461685  0.702390  ...  0.540544  0.411193  0.000000
# 4   0.543481  0.000000  0.000000  ...  0.428748  0.232409  0.016442
# 5   0.580534  0.353517  0.996252  ...  0.173725  0.353997  0.333158
# 6   0.543481  0.978440  0.489245  ...  0.438158  0.546938  0.012703
# 7   0.499188  1.000000  0.565942  ...  0.480934  1.000000  0.141721
# 8   1.000000  0.689982  0.283379  ...  0.214604  0.614331  0.620271
# 9   0.000000  0.461685  0.702390  ...  0.148166  0.000000  0.007906
# 10  0.067735  0.520835  0.645714  ...  0.791238  0.593028  0.323379
# 11  0.265899  0.299081  0.743074  ...  0.000000  0.409480  0.332198
# 12  0.053501  0.370190  0.645714  ...  0.035993  0.189097  1.000000
# ...

# %%
trans = RobustScaler()
df_robust = trans.fit_transform(df_knn_s)
# convert the array back to a dataframe
df_robust_s = pd.DataFrame(df_robust)
df_robust_s
# Out:
#          0         1         2    ...       200       201       202
# 0  -1.001663  0.553447 -0.776301  ... -0.161753  0.495294  0.000000
# 1   0.490265  1.258215 -0.776301  ...  0.321648  0.495294 -0.436398
# 2   0.043069  0.774833  1.545116  ...  1.912025 -0.097273 -0.265976
# 3   0.122221 -0.083774  0.247175  ...  0.504287  0.002932 -0.443875
# 4   0.043069 -1.391542 -2.816099  ...  0.161753 -0.608695 -0.392379
# 5   0.115127 -0.390170  1.528771  ... -0.619619 -0.192740  0.599590
# 6   0.043069  1.379986 -0.682396  ...  0.190585  0.467316 -0.404089
# 7  -0.043069  1.441057 -0.347902  ...  0.321648  2.017252  0.000000
# 8   0.930873  0.562900 -1.580224  ... -0.494369  0.697869  1.498843
# 9  -1.013854 -0.083774  0.247175  ... -0.697929 -1.403770 -0.419114
# 10 -0.882127  0.083774  0.000000  ...  1.272396  0.624993  0.568962
# 11 -0.496752 -0.544364  0.424609  ... -1.151897 -0.002932  0.596585
# 12 -0.909808 -0.342942  0.000000  ... -1.041617 -0.756865  2.688170
# ...

# %%
scaler_1 = StandardScaler()
# transform data
Standard_scaled_s = scaler_1.fit_transform(df_knn_s)
df_standard_scaled_s = pd.DataFrame(Standard_scaled_s )
df_standard_scaled_s
# Out:
#          0         1         2    ...       200       201       202
# 0  -1.256561  0.420124 -0.516875  ... -0.141221  0.528059 -0.391865
# 1   1.234845  1.318459 -0.516875  ...  0.417556  0.528059 -0.869351
# 2   0.488061  0.702315  1.614399  ...  2.255915 -0.203899 -0.682884
# 3   0.620240 -0.392111  0.422770  ...  0.628673 -0.080123 -0.877532
# 4   0.488061 -2.059061 -2.389596  ...  0.232728 -0.835624 -0.821188
# 5   0.608392 -0.782660  1.599392  ... -0.670481 -0.321823  0.264177
# 6   0.488061  1.473675 -0.430662  ...  0.266057  0.493500 -0.834000
# 7   0.344218  1.551519 -0.123566  ...  0.417556  2.408032 -0.391865
# 8   1.970625  0.432173 -1.254950  ... -0.525701  0.778286  1.248096
# 9  -1.276918 -0.392111  0.422770  ... -0.761002 -1.817727 -0.850440
# 10 -1.056944 -0.178546  0.195841  ...  1.516551  0.688267  0.230665
# 11 -0.413399 -0.979204  0.585670  ... -1.285756 -0.087365  0.260889
# 12 -1.103170 -0.722461  0.195841  ... -1.158280 -1.018649  2.549401
# ...

# %%
scaler_ns = MinMaxScaler()
# transform data
Min_Max_scaled_ns = scaler.fit_transform(df_knn_ns)
df_minmax_ns = pd.DataFrame(Min_Max_scaled_ns)
df_minmax_ns
# Out:
#          0         1         2    ...       212       213       214
# 0   0.049736  0.203013  0.001929  ...  0.012448  0.174808  0.000000
# 1   0.017638  0.109754  0.035252  ...  0.223871  0.184556  0.262549
# 2   0.095446  0.287167  0.072096  ...  1.000000  0.535525  0.364316
# 3   0.060432  0.480859  0.461506  ...  0.580043  0.537670  0.006011
# 4   0.013755  0.100966  0.526817  ...  0.147655  0.066222  0.003440
# 5   0.328573  0.320667  0.818827  ...  0.686462  0.777654  0.027451
# 6   0.002058  0.022349  0.443401  ...  0.076688  0.009485  0.002449
# 7   0.000000  0.000000  0.443401  ...  0.056983  0.000000  0.002516
# 8   0.067165  0.751630  0.697731  ...  0.408964  0.440196  0.237648
# 9   0.121899  0.573666  0.695565  ...  0.859113  0.206081  0.044432
# 10  0.023845  0.349320  0.564678  ...  0.550676  0.749511  0.369283
# 11  0.328573  0.014352  0.564678  ...  0.547734  0.886376  0.347488
# 12  0.193912  0.583867  0.528651  ...  0.190871  0.551851  0.027907
# ...

# %%
trans_ns = RobustScaler()
df_robust_ns = trans.fit_transform(df_knn_ns)
# convert the array back to a dataframe
df_robust_ns = pd.DataFrame(df_robust_ns)
df_robust_ns
# Out:
#          0         1         2    ...       212       213       214
# 0  -0.214797 -0.443640 -2.355221  ... -1.376756 -0.627723 -0.688632
# 1  -0.365628 -0.726422 -2.205697  ... -0.790581 -0.604830  0.000000
# 2   0.000000 -0.188465 -2.040374  ...  1.361250  0.219473  0.266922
# 3  -0.164533  0.398856 -0.293058  ...  0.196913  0.224510 -0.672867
# 4  -0.383875 -0.753070  0.000000  ... -1.001893 -0.882754 -0.679608
# 5   1.095481 -0.086883  1.310277  ...  0.491961  0.788149 -0.616632
# 6  -0.438840 -0.991455 -0.374294  ... -1.198649 -1.016011 -0.682208
# 7  -0.448508 -1.059224 -0.374294  ... -1.253280 -1.038287 -0.682033
# 8  -0.132896  1.219901  0.766909  ... -0.277407 -0.004420 -0.065312
# 9   0.124305  0.680269  0.757191  ...  0.970638 -0.554275 -0.572094
# 10 -0.336459  0.000000  0.169889  ...  0.115491  0.722051  0.279948
# 11  1.095481 -1.015706  0.169889  ...  0.107334  1.043499  0.222782
# 12  0.462699  0.711203  0.008231  ... -0.882074  0.257816 -0.615436
# ...

# %%
scaler_ns = StandardScaler()
# transform data
Standard_scaled_ns = scaler_1.fit_transform(df_knn_ns)
df_standard_scaled_ns = pd.DataFrame(Standard_scaled_ns )
df_standard_scaled_ns
# Out:
#          0         1         2    ...       212       213       214
# 0  -0.594838 -0.667338 -1.850011  ... -1.589131 -1.033035 -1.006044
# 1  -0.735522 -1.007064 -1.723854  ... -0.782398 -0.998005 -0.125873
# 2  -0.394491 -0.360777 -1.584368  ...  2.179090  0.263323  0.215291
# 3  -0.547955  0.344813 -0.110129  ...  0.576654  0.271030 -0.985893
# 4  -0.752541 -1.039078  0.137129  ... -1.073219 -1.423277 -0.994510
# 5   0.627295 -0.238740  1.242632  ...  0.982719  1.133497 -0.914017
# 6  -0.803808 -1.325467 -0.178669  ... -1.344008 -1.627182 -0.997833
# 7  -0.812827 -1.406883 -0.178669  ... -1.419195 -1.661269 -0.997608
# 8  -0.518446  1.331193  0.784183  ... -0.076135 -0.079273 -0.209351
# 9  -0.278548  0.682894  0.775984  ...  1.641505 -0.920646 -0.857091
# 10 -0.708315 -0.134361  0.280467  ...  0.464596  1.032354  0.231940
# 11  0.627295 -1.354601  0.280467  ...  0.453370  1.524226  0.158874
# 12  0.037082  0.720058  0.144074  ... -0.908317  0.321995 -0.912488
# ...

# %%
plt.figure(figsize=(50,50))
sns.boxplot(data=df_minmax_s)

# %%
plt.figure(figsize=(50,50))
sns.boxplot(data=df_robust_s)

# %%
plt.figure(figsize=(50,50))
sns.boxplot(data=df_standard_scaled_s)

# %%
plt.figure(figsize=(50,50))
sns.boxplot(data=df_minmax_ns)

# %%
plt.figure(figsize=(50,50))
sns.boxplot(data=df_robust_ns)

# %%
plt.figure(figsize=(50,50))
sns.boxplot(data=df_standard_scaled_s)
